# %% [markdown]
# # Características Linguisticas de un texto usando SpaCy
#
# El procesamiento sintáctico y semantico de texto puede llegar a ser muy complicado si no se cuenta con un modelo lo suficientemente completo para llevar a cabo esta tarea. En este cuaderno se mostrarán algunas soluciones que nos proporciona el paquete [SpaCy](https://spacy.io/)  para llevar a cabo esta tarea:

# %% [markdown]
# ## Cargamos un modelo en español de spaCy
#
# Los modelos en Spacy han sido pre entrenados en diferentes idiomas y  se pueden encontrar en [spaCy - Models](https://spacy.io/models). En ese directorio se encuentran dos tipos de modelos:
#
#
# * **Core Models** modelos pre-entrenados de uso general para predecir '*named entities recognition*', etiquetas de parte del discurso y dependencias sintácticas. Está listo para usar en datos más específicos.
#
# * **Starter Models** Usando paquetes con pesos preentrenados se puede inicializar modelos para lograr una mayor precisión. Entre ellos se puede incluir vectores de palabras (que se utilizarán como características durante el entrenamiento) u otras representaciones previamente formadas como BERT. Estos modelos no incluyen componentes para tareas específicas como NER o clasificación de texto y están destinados a ser utilizados como modelos base al entrenar sus propios modelos.

# %%
#!pip install spacy
#!python -m spacy download es_core_news_sm

# %%
import spacy
import es_core_news_sm
nlp=spacy.load("es_core_news_sm")
from spacy import displacy

# %%
texto="La Ocde le dio respaldo total a Colombia en la aplicación de la devolución del IVA."
doc=nlp(texto)

# %% [markdown]
# ## Tagueo POS
#
# Identificamos los lemas y características de las palabras en el documento:

# %%
TOK=[]
for token in doc:
    TOK.append([token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop,token.ent_type_])

# %%
import pandas as pd 
TextAnalysis=pd.DataFrame(data=TOK,columns=["Text","Lemma","POS","Tag","Dep","Shape","alpha","stop","Tipo Entidad"])
TextAnalysis
# Out:
#           Text       Lemma    POS    Tag    Dep  Shape  alpha   stop  \
# 0           La          el    DET    DET    det     Xx   True   True
# 1         Ocde        Ocde  PROPN  PROPN  nsubj   Xxxx   True  False
# 2           le          él   PRON   PRON    obj     xx   True   True
# 3          dio         dar   VERB   VERB   ROOT    xxx   True   True
# 4     respaldo    respaldo   NOUN   NOUN    obj   xxxx   True  False
# 5        total       total    ADJ    ADJ   amod   xxxx   True   True
# 6            a           a    ADP    ADP   case      x   True  False
# 7     Colombia    Colombia  PROPN  PROPN   nmod  Xxxxx   True  False
# 8           en          en    ADP    ADP   case     xx   True   True
# 9           la          el    DET    DET    det     xx   True   True
# 10  aplicación  aplicación   NOUN   NOUN    obl   xxxx   True  False
# 11          de          de    ADP    ADP   case     xx   True   True
# 12          la          el    DET    DET    det     xx   True   True
# 13  devolución  devolución   NOUN   NOUN   nmod   xxxx   True  False
# 14         del         del    ADP    ADP   case    xxx   True   True
# 15         IVA         IVA  PROPN  PROPN   nmod    XXX   True  False
# 16           .           .  PUNCT  PUNCT  punct      .  False  False
#
#    Tipo Entidad
# 0
# 1           ORG
# 2
# 3
# 4
# 5
# 6
# 7           LOC
# 8
# 9
# 10
# 11
# 12
# 13
# 14
# 15
# 16

# %% [markdown]
# [Atributos de Token en Spacy](https://spacy.io/api/token#attributes)

# %% [markdown]
# ## Análisis gramátical de dependencia
#
# La clase pasada vimos como generar un arbol que expresaba el análisis de dependencia de las palabras dispuestas en una oración:

# %%
displacy.serve(doc, style="dep")
# Out:
# /home/isaac/anaconda3/lib/python3.8/site-packages/spacy/displacy/__init__.py:97: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   warnings.warn(Warnings.W011)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="es">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="es" id="5aeef36d57774334ba910e6fcf69e995-0" class="displacy" width="2850" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">La</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Ocde</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">le</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">dio</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">respaldo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">total</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">Colombia</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">en</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">la</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">aplicación</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">la</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">devolución</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">del</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">IVA.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5aeef36d57774334ba910e6fcf69e995-0-0" stroke-width="2px" d="M70,352.0 C70,264.5 210.0,264.5 210.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5aeef36d57774334ba910e6fcf69e995-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,354.0 L62,342.0 78,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5aeef36d57774334ba910e6fcf69e995-0-1" stroke-width="2px" d="M245,352.0 C245,177.0 565.0,177.0 565.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5aeef36d57774334ba910e6fcf69e995-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,354.0 L237,342.0 253,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5aeef36d57774334ba910e6fcf69e995-0-2" stroke-width="2px" d="M420,352.0 C420,264.5 560.0,264.5 560.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5aeef36d57774334ba910e6fcf69e995-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,354.0 L412,342.0 428,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5aeef36d57774334ba910e6fcf69e995-0-3" stroke-width="2px" d="M595,352.0 C595,264.5 735.0,264.5 735.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5aeef36d57774334ba910e6fcf69e995-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M735.0,354.0 L743.0,342.0 727.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5aeef36d57774334ba910e6fcf69e995-0-4" stroke-width="2px" d="M770,352.0 C770,264.5 910.0,264.5 910.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5aeef36d57774334ba910e6fcf69e995-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M910.0,354.0 L918.0,342.0 902.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5aeef36d57774334ba910e6fcf69e995-0-5" stroke-width="2px" d="M1120,352.0 C1120,264.5 1260.0,264.5 1260.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5aeef36d57774334ba910e6fcf69e995-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPa
# Using the 'dep' visualizer
# Serving on http://0.0.0.0:5000 ...
# 127.0.0.1 - - [10/Apr/2021 09:31:57] "GET / HTTP/1.1" 200 13408
# 127.0.0.1 - - [10/Apr/2021 09:31:57] "GET /favicon.ico HTTP/1.1" 200 13408
# Shutting down server on port 5000.

# %% [markdown]
# Para ver el valor de cada dependencia puede consultar en [Syntactic Dependency Parsing](https://spacy.io/api/annotation#dependency-parsing)

# %%
doc=nlp('A mi me gustan los gatos, los perros, los loros y los ratones')
displacy.render(doc, style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="es" id="41184556026644529cc87f77340c0547-0" class="displacy" width="2325" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">A</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">mi</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">me</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">gustan</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">los</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">gatos,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">los</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">perros,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">los</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">loros</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">y</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">los</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">ratones</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-41184556026644529cc87f77340c0547-0-0" stroke-width="2px" d="M70,352.0 C70,264.5 210.0,264.5 210.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-41184556026644529cc87f77340c0547-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,354.0 L62,342.0 78,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-41184556026644529cc87f77340c0547-0-1" stroke-width="2px" d="M245,352.0 C245,177.0 565.0,177.0 565.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-41184556026644529cc87f77340c0547-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,354.0 L237,342.0 253,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-41184556026644529cc87f77340c0547-0-2" stroke-width="2px" d="M420,352.0 C420,264.5 560.0,264.5 560.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-41184556026644529cc87f77340c0547-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,354.0 L412,342.0 428,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-41184556026644529cc87f77340c0547-0-3" stroke-width="2px" d="M770,352.0 C770,264.5 910.0,264.5 910.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-41184556026644529cc87f77340c0547-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,354.0 L762,342.0 778,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-41184556026644529cc87f77340c0547-0-4" stroke-width="2px" d="M595,352.0 C595,177.0 915.0,177.0 915.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-41184556026644529cc87f77340c0547-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M915.0,354.0 L923.0,342.0 907.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-41184556026644529cc87f77340c0547-0-5" stroke-width="2px" d="M1120,352.0 C1120,264.5 1260.0,264.5 1260.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-41184556026644529cc87f77340c0547-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1120,354.0 L1112,342.0 1128,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-41184556026644529cc87f77340c0547-0-6" stroke-width="2px" d="M595,352.0 C595,89.5 1270.0,89.5 1270.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-41184556026644529cc87f77340c0547-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1270.0,354.0 L1278.0,342.0 1262.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-41184556026644529cc87f77340c0547-0-7" stroke-width="2px" d="M1470,352.0 C1470,264.5 1610.0,264.5 1610.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-41184556026644529cc87f77340c0547-0-7" class="displacy-label" startOffset="

# %% [markdown]
# ## Sintagmas nominales
#
# Los sintagmas nominales son "frases nominales básicas", frases planas que tienen un sustantivo como cabeza. Puede pensar en los sintagmas de sustantivos como un sustantivo más las palabras que describen el sustantivo, por ejemplo, "el joven sin gracia" o "el fondo tecnológico más grande del mundo". Para obtener los fragmentos de sustantivo en un documento, simplemente itere sobre Doc.noun_chunks

# %%
NOUN_CHUNK=[]
for chunk in doc.noun_chunks:
    NOUN_CHUNK.append([chunk.text, chunk.root.text, chunk.root.dep_,
            chunk.root.head.text])
    
pd.DataFrame(data=NOUN_CHUNK,columns=["Text","Root.text","Root.dep_","root.head.text"])
# Out:
#             Text   Root.text Root.dep_ root.head.text
# 0        La Ocde        Ocde     nsubj            dio
# 1             le          le       obj            dio
# 2       respaldo    respaldo       obj            dio
# 3       Colombia    Colombia      nmod       respaldo
# 4  la aplicación  aplicación       obl            dio
# 5  la devolución  devolución      nmod     aplicación
# 6            IVA         IVA      nmod     devolución

# %% [markdown]
# ## Comparemos con el modelo en Inglés
#
# Una dificultad con buena parte de los modelos en español es que no son tan eficientes y detallados como los que tenemos en inglés:

# %%
nlp2=spacy.load("en_core_web_sm")
texto2="OECD gave full support to Colombia in the application of the VAT refund."
doc2=nlp2(texto2)

# %%
NOUN_CHUNK=[]
for chunk in doc2.noun_chunks:
    NOUN_CHUNK.append([chunk.text, chunk.root.text, chunk.root.dep_,
            chunk.root.head.text])
    
pd.DataFrame(data=NOUN_CHUNK,columns=["Text","Root.text","Root.dep_","root.head.text"])
# Out:
#               Text    Root.text Root.dep_ root.head.text
# 0             OECD         OECD     nsubj           gave
# 1     full support      support      dobj           gave
# 2         Colombia     Colombia      pobj             to
# 3  the application  application      pobj             in
# 4   the VAT refund       refund      pobj             of

# %% [markdown]
# ## Información del análisis de dependencia en una tabla
#
# Los comandos `head` y `child` nos permite explorar en los diferentes arcos obtenidos por el análisis de dependencias.

# %%
Dep_Tree=[]
for token in doc:
    Dep_Tree.append([token.text, token.dep_, token.head.text, token.pos_,
            [child for child in token.children],[anc for anc in token.ancestors]])
pd.DataFrame(data=Dep_Tree,columns=["Text","Dep","Head","POS","Children","Ancestors"])
# Out:
#           Text    Dep        Head    POS                             Children  \
# 0           La    det        Ocde    DET                                   []
# 1         Ocde  nsubj         dio  PROPN                                 [La]
# 2           le    obj         dio   PRON                                   []
# 3          dio   ROOT         dio   VERB  [Ocde, le, respaldo, aplicación, .]
# 4     respaldo    obj         dio   NOUN                    [total, Colombia]
# 5        total   amod    respaldo    ADJ                                   []
# 6            a   case    Colombia    ADP                                   []
# 7     Colombia   nmod    respaldo  PROPN                                  [a]
# 8           en   case  aplicación    ADP                                   []
# 9           la    det  aplicación    DET                                   []
# 10  aplicación    obl         dio   NOUN                 [en, la, devolución]
# 11          de   case  devolución    ADP                                   []
# 12          la    det  devolución    DET                                   []
# 13  devolución   nmod  aplicación   NOUN                        [de, la, IVA]
# 14         del   case         IVA    ADP                                   []
# 15         IVA   nmod  devolución  PROPN                                [del]
# 16           .  punct         dio  PUNCT                                   []
#
#                              Ancestors
# 0                          [Ocde, dio]
# 1                                [dio]
# 2                                [dio]
# 3                                   []
# 4                                [dio]
# 5                      [respaldo, dio]
# 6            [Colombia, respaldo, dio]
# 7                      [respaldo, dio]
# 8                    [aplicación, dio]
# 9                    [aplicación, dio]
# 10                               [dio]
# 11       [devolución, aplicación, dio]
# 12       [devolución, aplicación, dio]
# 13                   [aplicación, dio]
# 14  [IVA, devolución, aplicación, dio]
# 15       [devolución, aplicación, dio]
# 16                               [dio]

# %% [markdown]
# Debido a que las relaciones sintácticas forman un árbol, cada palabra tiene exactamente una '*head*'. Por lo tanto, se puede iterar sobre los arcos en el árbol iterando sobre las palabras en la oración.
#
# Esta suele ser la mejor manera de hacer coincidir un arco de interés, desde abajo:

# %%
from spacy.symbols import nsubj, VERB
verbs = []
sujeto=[]
for possible_subject in doc:
    if possible_subject.dep == nsubj and possible_subject.head.pos == VERB:
        verbs.append(possible_subject.head)
        sujeto.append(possible_subject)
print(verbs)
print(sujeto)
# Out:
# [dio]
# [Ocde]

# %% [markdown]
# Ahora desde arriba, observe que se debe iterar dos veces:

# %%
verbs = []
for possible_verb in doc:
    if possible_verb.pos == VERB:
        for possible_subject in possible_verb.children:
            if possible_subject.dep == nsubj:
                verbs.append(possible_verb)
                break
                
verbs
# Out:
# [dio]

# %% [markdown]
# Podemos determinar en cada palabra su cabeza sintáctica:

# %%
doc3 = nlp("Los titulares de cuentas de crédito e hipotecas deben presentar sus solicitudes")
root = [token for token in doc3 if token.head == token][0]
subject = list(root.lefts)[0]
Sintac_head=[]
for descendant in subject.subtree:
    assert subject is descendant or subject.is_ancestor(descendant)
    Sintac_head.append([descendant.text, descendant.dep_, descendant.n_lefts,
            descendant.n_rights,
            [ancestor.text for ancestor in descendant.ancestors]])

pd.DataFrame(data=Sintac_head,columns=["Text","Dep","n_lefts","n_rights","ancestors"])
# Out:
#         Text    Dep  n_lefts  n_rights  \
# 0        Los    det        0         0
# 1  titulares  nsubj        1         1
# 2         de   case        0         0
# 3    cuentas   nmod        1         1
# 4         de   case        0         0
# 5    crédito   nmod        1         1
# 6          e     cc        0         0
# 7  hipotecas   conj        1         0
#
#                                            ancestors
# 0                             [titulares, presentar]
# 1                                        [presentar]
# 2                    [cuentas, titulares, presentar]
# 3                             [titulares, presentar]
# 4           [crédito, cuentas, titulares, presentar]
# 5                    [cuentas, titulares, presentar]
# 6  [hipotecas, crédito, cuentas, titulares, prese...
# 7           [crédito, cuentas, titulares, presentar]

# %% [markdown]
# ## Reconocimiento de entidades con nombre
#
# Una entidad con nombre es un "objeto del mundo real" al que se le asigna un nombre, por ejemplo, una persona, un país, un producto o el título de un libro. spaCy puede reconocer varios tipos de entidades con nombre en un documento, pidiéndole al modelo una predicción. Debido a que los modelos son estadísticos y dependen en gran medida de los ejemplos en los que fueron entrenados, esto no siempre funciona a la perfección y podría necesitar algún ajuste posterior, dependiendo de su caso de uso.

# %%
ENT=[]
doc4 = nlp("El Gobierno de Colombia abrió la puerta a una compra de acciones en la mayor aerolínea del país, Avianca, la cual está teniendo dificultades para mantenerse a flote ante la pandemia de coronavirus. ")

for ent in doc4.ents:
    ENT.append([ent.text, ent.start_char, ent.end_char, ent.label_])
    
pd.DataFrame(data=ENT,columns=["Text","Inicio","Final","Etiqueta"])
# Out:
#                    Text  Inicio  Final Etiqueta
# 0  Gobierno de Colombia       3     23      LOC
# 1               Avianca      97    104      ORG

# %% [markdown]
# ## Visualización NER

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
doc=nlp('Se le conoce principalmente por ser el autor de la obra The Art of Computer Programming (El arte de programar computadoras), una de las más respetadas referencias en el campo de las ciencias de la computación. Sentó las bases y dio nombre al análisis de algoritmos, y ha realizado numerosos aportes a varias ramas teóricas de la informática. Es el creador de TEX, del sistema de diseño de tipos METAFONT y del estilo de programación conocido como programación literaria (Literate programming). Knuth es conocido como el "padre del análisis de algoritmos". Knuth es un programador conocido por su humor geek: ofrece una recompensa de 2,56 dólares a quien encuentre errores conceptuales o tipográficos en sus libros (la razón detrás de la extraña cifra es que "256 centavos son 1 dólar hexadecimal"), y por otro lado ofrecía 3,16 por errores en 3:16 Bible Texts Illuminated. Numeró las distintas versiones de TEX de manera que se aproximaran al número π (3, 3.1, 3.14, etc.), al igual que los números de versión de MetaFont se van aproximando a e. Su cita más célebre, al enviarle sus comentarios a un colega autor de un algoritmo, es: "Cuidado con los errores en el código anterior; sólo he demostrado que es correcto, no lo he probado". Knuth es el autor de 3:16 Bible Texts Illuminated (1991, ISBN 0-89579-252-4), libro en el que intenta examinar la Biblia por un proceso de "muestreo estratificado aleatorio", es decir, un análisis del capítulo 3, versículo 16 de cada libro. Cada versículo se acompaña de un renderizado en arte caligráfico, realizado por un grupo de calígrafos capitaneado por Hermann Zapf. Ha sido galardonado con el Premio Fundación BBVA Fronteras del Conocimiento 2010 en la categoría de Tecnologías de la Información y la Comunicación. Está casado con Jill Carter Knuth. Tienen dos hijos. ')
for sent in doc.sents:
    displacy.render(nlp(sent.text), style="ent",jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Se le conoce principalmente por ser el autor de la obra
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Art of Computer Programming
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  (El arte de programar computadoras), una de las más respetadas referencias en el campo de las ciencias de la computación.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Sentó las bases y dio nombre al análisis de algoritmos, y ha realizado numerosos aportes a varias ramas teóricas de la informática.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Es el creador de
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TEX
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# , del sistema de diseño de tipos METAFONT y del estilo de programación conocido como programación literaria (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Literate
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  programming).</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Knuth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  es conocido como el &quot;padre del análisis de algoritmos&quot;.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Knuth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  es un programador conocido por su humor geek: ofrece una recompensa de 2,56 dólares a quien encuentre errores conceptuales o tipográficos en sus libros (la razón detrás de la extraña cifra es que &quot;256 centavos son 1 dólar hexadecimal&quot;), y por otro lado ofrecía 3,16 por errores en 3:16
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bible Texts Illuminated
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# .</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Numeró
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  las distintas versiones de TEX de manera que se aproximaran al número π (3, 3.1, 3.14, etc.), al igual que los números de versión de MetaFont se van aproximando a e. Su cita más célebre, al enviarle sus comentarios a un colega autor de un algoritmo, es: &quot;Cuidado con los errores en el código anterior; sólo he demostrado que es correcto, no lo he probado&quot;.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Knuth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  es el autor de 3:16
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bible Texts Illuminated
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  (1991, ISBN 0-89579-252-4), libro en el que intenta examinar
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     la Biblia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  por un proceso de &quot;muestreo estratificado aleatorio&quot;, es decir, un análisis del capítulo 3, versículo 16 de cada libro.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Cada versículo se acompaña de un renderizado en arte caligráfico, realizado por un grupo de calígrafos capitaneado por
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hermann Zapf
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# .</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Ha sido galardonado con el
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Premio Fundación BBVA Fronteras del Conocimiento 2010
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  en la categoría de
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tecnologías de la Información
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  y la
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Comunicación
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# .</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Está
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  casado con
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jill Carter Knuth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# .</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Tienen dos hijos.</div></span>

# %%
doc2=nlp2("Donald Ervin Knuth is an American computer scientist, mathematician, and professor emeritus at Stanford University. He is the 1974 recipient of the ACM Turing Award, informally considered the Nobel Prize of computer science. He is the author of the multi-volume work The Art of Machine Programming. He contributed to the development of the rigorous analysis of the computational complexity of algorithms and systematized formal mathematical techniques for it. In the process he also popularized the asymptotic notation. In addition to fundamental contributions in several branches of theoretical computer science, Knuth is the creator of the TeX computer typesetting system, the related METAFONT font definition language and rendering system, and the Computer Modern family of typefaces. As a writer and scholar, Knuth created the WEB and CWEB computer programming systems designed to encourage and facilitate literate programming, and designed the MIX/MMIX instruction set architectures. Knuth strongly opposes granting software patents, having expressed his opinion to the United States Patent and Trademark Office and European Patent Organisation. For Donald one hexadecimal dollar is 2.56 dollars")

# %%
for sent in doc2.sents:
    displacy.render(nlp2(sent.text), style="ent",jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Donald Ervin Knuth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is an
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     American
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  computer scientist, mathematician, and professor emeritus at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Stanford University
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">He is the
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1974
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  recipient of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the ACM Turing Award
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , informally considered
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Nobel Prize
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  of computer science.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">He is the author of the multi-volume work
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Art of Machine Programming
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# .</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">He contributed to the development of the rigorous analysis of the computational complexity of algorithms and systematized formal mathematical techniques for it.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">In the process he also popularized the asymptotic notation.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">In addition to fundamental contributions in several branches of theoretical computer science,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Knuth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is the creator of the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TeX
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  computer typesetting system, the related
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     METAFONT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  font definition language and rendering system, and the Computer Modern family of typefaces.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">As a writer and scholar,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Knuth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  created the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     WEB
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CWEB
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  computer programming systems designed to encourage and facilitate literate programming, and designed the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MIX/MMIX
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  instruction set architectures.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Knuth strongly opposes granting software patents, having expressed his opinion to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  Patent and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trademark Office
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     European Patent Organisation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">For
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Donald
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  hexadecimal dollar is
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2.56 dollars
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </div></span>

# %%
ENT=[]
for ent in doc2.ents:
    ENT.append([ent.text, ent.start_char, ent.end_char, ent.label_])
    
pd.DataFrame(data=ENT,columns=["Text","Inicio","Final","Etiqueta"])
# Out:
#                                              Text  Inicio  Final     Etiqueta
# 0                              Donald Ervin Knuth       0     18       PERSON
# 1                                        American      25     33         NORP
# 2                             Stanford University      95    114          ORG
# 3                                            1974     126    130         DATE
# 4                                 the Nobel Prize     188    203  WORK_OF_ART
# 5                  The Art of Machine Programming     267    297  WORK_OF_ART
# 6                                           Knuth     614    619       PERSON
# 7                                             TeX     642    645       PERSON
# 8                                          Modern     760    766       PERSON
# 9                                           Knuth     813    818       PERSON
# 10                                            WEB     831    834          ORG
# 11                                           CWEB     839    843          ORG
# 12                                          Knuth     989    994          ORG
# 13  the United States Patent and Trademark Office    1071   1116          ORG
# 14                   European Patent Organisation    1121   1149          ORG
# 15                                         Donald    1155   1161       PERSON
# 16                                   2.56 dollars    1188   1200        MONEY

# %%
ENT=[]
for ent in doc.ents:
    ENT.append([ent.text, ent.start_char, ent.end_char, ent.label_])
    
pd.DataFrame(data=ENT,columns=["Text","Inicio","Final","Etiqueta"])
# Out:
#                                                  Text  Inicio  Final Etiqueta
# 0                     The Art of Computer Programming      56     87     MISC
# 1                   El arte de programar computadoras      89    122     MISC
# 2                                               Sentó     210    215      ORG
# 3                                Es el creador de TEX     342    362     MISC
# 4                                            METAFONT     395    403      ORG
# 5                                Literate programming     471    491      PER
# 6                                               Knuth     494    499      PER
# 7                                               Knuth     556    561      PER
# 8                             Bible Texts Illuminated     848    871     MISC
# 9                                              Numeró     873    879      PER
# 10                                                TEX     907    910     MISC
# 11                                           MetaFont    1013   1021      LOC
# 12                                Su cita más célebre    1046   1065     MISC
# 13                                              Knuth    1237   1242      PER
# 14                            Bible Texts Illuminated    1263   1286     MISC
# 15                                               ISBN    1294   1298      ORG
# 16                                          la Biblia    1348   1357     MISC
# 17                                     Cada versículo    1478   1492     MISC
# 18                                       Hermann Zapf    1597   1609      PER
# 19                                Ha sido galardonado    1611   1630     MISC
# 20  Premio Fundación BBVA Fronteras del Conocimien...    1638   1691     MISC
# 21                                        Tecnologías    1711   1722      LOC
# 22                                        Información    1729   1740      LOC
# 23                                       Comunicación    1746   1758      LOC
# 24                                               Está    1760   1764      PER
# 25                                  Jill Carter Knuth    1776   1793      PER
# 26                                   Tienen dos hijos    1795   1811     MISC

# %%
texto="Las tradicionales y multitudinarias marchas que colman las plazas principales de las capitales del país cada primero de mayo se transformaron, debido a la cuarentena por el coronavirus, en charlas y arengas virtuales en las que la crisis económica y la pérdida de cientos de empleos por la covid-19 fueron los principales puntos. En Medellín, por ejemplo, Jaime Montoya, presidente de la Central Unitaria de Trabajadores (CUT) Antioquia, manifestó que a pesar del confinamiento, la movilización social no se detiene y pasó de la calle a la virtualidad."
doc=nlp(texto)

# %%
displacy.render(doc,style='dep')
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="es" id="49d9a1f5bd1a440f87860f9999d46f5f-0" class="displacy" width="15450" height="1362.0" direction="ltr" style="max-width: none; height: 1362.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Las</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">tradicionales</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">y</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">multitudinarias</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">marchas</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">que</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">colman</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">las</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">plazas</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">principales</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">las</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">capitales</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">del</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">país</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">cada</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">primero</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">mayo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">se</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">transformaron,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">debido</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">la</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">cuarentena</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">por</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">el</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">coronavirus,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">en</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">charlas</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">y</tspan>
#     <tspan clas

# %%
from spacy.symbols import nsubj, VERB
verbs = []
sujeto=[]
for possible_subject in doc:
    if possible_subject.dep == nsubj and possible_subject.head.pos == VERB:
        verbs.append([possible_subject.head,[child for child in possible_subject.head.children]])
        sujeto.append(possible_subject)
print(verbs)
print(sujeto)
# Out:
# [[transformaron, [marchas, se, cuarentena, .]], [colman, [que, plazas, primero]], [manifestó, [Medellín, Jaime, detiene, .]], [detiene, [que, confinamiento, movilización, no, se, pasó]]]
# [marchas, que, Jaime, movilización]

# %%
NOUN_CHUNK=[]
for chunk in doc.noun_chunks:
    NOUN_CHUNK.append([chunk.text, chunk.root.text, chunk.root.dep_,
            chunk.root.head.text])
    
pd.DataFrame(data=NOUN_CHUNK,columns=["Text","Root.text","Root.dep_","root.head.text"])
# Out:
#                                    Text      Root.text Root.dep_  \
# 0                                   que            que     nsubj
# 1                            las plazas         plazas       obj
# 2                         las capitales      capitales      nmod
# 3                                  país           país      nmod
# 4                                  mayo           mayo      nmod
# 5                                    se             se       obj
# 6                         la cuarentena     cuarentena       obl
# 7                        el coronavirus    coronavirus      nmod
# 8                               charlas        charlas      nmod
# 9                               arengas        arengas      conj
# 10                              las que            que       obl
# 11                            la crisis         crisis     nsubj
# 12                           la pérdida        pérdida      conj
# 13                              empleos        empleos      nmod
# 14                          la covid-19       covid-19      nmod
# 15               los principales puntos         puntos       acl
# 16                             Medellín       Medellín       obl
# 17                              ejemplo        ejemplo     fixed
# 18                        Jaime Montoya          Jaime     nsubj
# 19                           presidente     presidente     appos
# 20  la Central Unitaria de Trabajadores        Central      nmod
# 21                                  CUT            CUT      flat
# 22                            Antioquia      Antioquia     appos
# 23                                pesar          pesar     fixed
# 24                        confinamiento  confinamiento       obl
# 25                      la movilización   movilización     nsubj
# 26                                   se             se       obj
# 27                             la calle          calle       obl
# 28                       la virtualidad    virtualidad       obl
#
#    root.head.text
# 0          colman
# 1          colman
# 2          plazas
# 3       capitales
# 4         primero
# 5   transformaron
# 6   transformaron
# 7      cuarentena
# 8     coronavirus
# 9         charlas
# 10         puntos
# 11         puntos
# 12         crisis
# 13        cientos
# 14        pérdida
# 15        charlas
# 16      manifestó
# 17            por
# 18      manifestó
# 19          Jaime
# 20     presidente
# 21        Central
# 22     presidente
# 23              a
# 24        detiene
# 25        detiene
# 26        detiene
# 27           pasó
# 28           pasó

# %%
root = [token for token in doc if token.head == token][0]
subject = list(root.children)[0]
Sintac_head=[]
for descendant in subject.subtree:
    assert subject is descendant or subject.is_ancestor(descendant)
    Sintac_head.append([descendant.text, descendant.dep_, descendant.n_lefts,
            descendant.n_rights,
            [ancestor.text for ancestor in descendant.ancestors]])

pd.DataFrame(data=Sintac_head,columns=["Text","Dep","n_lefts","n_rights","ancestors"])
# Out:
#                Text     Dep  n_lefts  n_rights  \
# 0               Las     det        0         0
# 1     tradicionales    amod        0         1
# 2                 y      cc        0         0
# 3   multitudinarias    conj        1         0
# 4           marchas   nsubj        2         1
# 5               que   nsubj        0         0
# 6            colman     acl        1         2
# 7               las     det        0         0
# 8            plazas     obj        1         2
# 9       principales    amod        0         0
# 10               de    case        0         0
# 11              las     det        0         0
# 12        capitales    nmod        2         1
# 13              del    case        0         0
# 14             país    nmod        1         0
# 15             cada     det        0         0
# 16          primero  advmod        1         1
# 17               de    case        0         0
# 18             mayo    nmod        1         0
#
#                                             ancestors
# 0                            [marchas, transformaron]
# 1                            [marchas, transformaron]
# 2   [multitudinarias, tradicionales, marchas, tran...
# 3             [tradicionales, marchas, transformaron]
# 4                                     [transformaron]
# 5                    [colman, marchas, transformaron]
# 6                            [marchas, transformaron]
# 7            [plazas, colman, marchas, transformaron]
# 8                    [colman, marchas, transformaron]
# 9            [plazas, colman, marchas, transformaron]
# 10  [capitales, plazas, colman, marchas, transform...
# 11  [capitales, plazas, colman, marchas, transform...
# 12           [plazas, colman, marchas, transformaron]
# 13  [país, capitales, plazas, colman, marchas, tra...
# 14  [capitales, plazas, colman, marchas, transform...
# 15          [primero, colman, marchas, transformaron]
# 16                   [colman, marchas, transformaron]
# 17    [mayo, primero, colman, marchas, transformaron]
# 18          [primero, colman, marchas, transformaron]
